# %% [markdown]
# # [Effective TensorFlow for Non-Experts (Google IO '17)](http://youtu.be/?v=5DknTFbcGVM)
# c:\Users\hcche\Documents\ML YouTube and Moocs\Machine Learning\Misc of ML and AI\Inception slim models API\Effective TensorFlow for Non-Experts (Google I_O '17)-5DknTFbcGVM.mp4
# # [Estimator demo using Automobile dataset](https://gist.github.com/martinwicke/6838c23abdc53e6bcda36ed9f40cff39)
# [Jupyter Notebook martinwicke/automobile.ipynb](https://goo.gl/0OgXiL)

# %%
from __future__ import print_function
from __future__ import division
from __future__ import absolute_import

# %%
# First thing to do: Download https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data

# %%
# We're using pandas to read the CSV file. This is easy for small datasets, but for large and complex datasets,
# tensorflow parsing and processing functions are more powerful.
import pandas as pd
import numpy as np

# %%
# The CSV file does not have a header, so we have to fill in column names.
names = [
    'symboling', 
    'normalized-losses', 
    'make', 
    'fuel-type', 
    'aspiration',
    'num-of-doors',
    'body-style',
    'drive-wheels',
    'engine-location',
    'wheel-base',
    'length',
    'width',
    'height',
    'curb-weight',
    'engine-type',
    'num-of-cylinders',
    'engine-size',
    'fuel-system',
    'bore',
    'stroke',
    'compression-ratio',
    'horsepower',
    'peak-rpm',
    'city-mpg',
    'highway-mpg',
    'price',
]

# We also have to specify dtypes.
dtypes = {
    'symboling': np.int32, 
    'normalized-losses': np.float32, 
    'make': str, 
    'fuel-type': str, 
    'aspiration': str,
    'num-of-doors': str,
    'body-style': str,
    'drive-wheels': str,
    'engine-location': str,
    'wheel-base': np.float32,
    'length': np.float32,
    'width': np.float32,
    'height': np.float32,
    'curb-weight': np.float32,
    'engine-type': str,
    'num-of-cylinders': str,
    'engine-size': np.float32,
    'fuel-system': str,
    'bore': np.float32,
    'stroke': np.float32,
    'compression-ratio': np.float32,
    'horsepower': np.float32,
    'peak-rpm': np.float32,
    'city-mpg': np.float32,
    'highway-mpg': np.float32,
    'price': np.float32,    
}

# %%
# Read the file.
df = pd.read_csv('imports-85.data', names=names, dtype=dtypes, na_values='?')

# %%
# Some rows don't have price data, we can't use those.
df = df.dropna(axis='rows', how='any', subset=['price'])

# %%
# Fill missing values in continuous columns with zeros instead of NaN.
float_columns = [k for k,v in dtypes.items() if v == np.float32]
df[float_columns] = df[float_columns].fillna(value=0., axis='columns')
# Fill missing values in continuous columns with '' instead of NaN (NaN mixed with strings is very bad for us).
string_columns = [k for k,v in dtypes.items() if v == str]
df[string_columns] = df[string_columns].fillna(value='', axis='columns')

# %%
# Split the data into a training set and an eval set.
training_data = df[:160]
eval_data = df[160:]

# Separate input features from labels
training_label = training_data.pop('price')
eval_label = eval_data.pop('price')

# %%
# Now we can start using some TensorFlow.
import tensorflow as tf
print('please make sure that version >= 1.2:')
print(tf.__version__)
# Out:
# please make sure that version >= 1.2:
# 1.4.0

# %%
# Make input function for training: 
#   num_epochs=None -> will cycle through input data forever
#   shuffle=True -> randomize order of input data
training_input_fn = tf.estimator.inputs.pandas_input_fn(x=training_data, y=training_label, batch_size=64, shuffle=True, num_epochs=None)

# Make input function for evaluation:
#   shuffle=False -> do not randomize input data
eval_input_fn = tf.estimator.inputs.pandas_input_fn(x=eval_data, y=eval_label, batch_size=64, shuffle=False)

# %%
# Describe how the model should interpret the inputs. The names of the feature columns have to match the names
# of the series in the dataframe.

symboling = tf.feature_column.numeric_column('symboling')
normalized_losses = tf.feature_column.numeric_column('normalized-losses')
make = tf.feature_column.categorical_column_with_hash_bucket('make', 50)
fuel_type = tf.feature_column.categorical_column_with_vocabulary_list('fuel-type', vocabulary_list=['diesel', 'gas'])
aspiration = tf.feature_column.categorical_column_with_vocabulary_list('aspiration', vocabulary_list=['std', 'turbo'])
num_of_doors = tf.feature_column.categorical_column_with_vocabulary_list('num-of-doors', vocabulary_list=['two', 'four'])
body_style = tf.feature_column.categorical_column_with_vocabulary_list('body-style', vocabulary_list=['hardtop', 'wagon', 'sedan', 'hatchback', 'convertible'])
drive_wheels = tf.feature_column.categorical_column_with_vocabulary_list('drive-wheels', vocabulary_list=['4wd', 'rwd', 'fwd'])
engine_location = tf.feature_column.categorical_column_with_vocabulary_list('engine-location', vocabulary_list=['front', 'rear'])
wheel_base = tf.feature_column.numeric_column('wheel-base')
length = tf.feature_column.numeric_column('length')
width = tf.feature_column.numeric_column('width')
height = tf.feature_column.numeric_column('height')
curb_weight = tf.feature_column.numeric_column('curb-weight')
engine_type = tf.feature_column.categorical_column_with_vocabulary_list('engine-type', ['dohc', 'dohcv', 'l', 'ohc', 'ohcf', 'ohcv', 'rotor'])
num_of_cylinders = tf.feature_column.categorical_column_with_vocabulary_list('num-of-cylinders', ['eight', 'five', 'four', 'six', 'three', 'twelve', 'two'])
engine_size = tf.feature_column.numeric_column('engine-size')
fuel_system = tf.feature_column.categorical_column_with_vocabulary_list('fuel-system', ['1bbl', '2bbl', '4bbl', 'idi', 'mfi', 'mpfi', 'spdi', 'spfi'])
bore = tf.feature_column.numeric_column('bore')
stroke = tf.feature_column.numeric_column('stroke')
compression_ratio = tf.feature_column.numeric_column('compression-ratio')
horsepower = tf.feature_column.numeric_column('horsepower')
peak_rpm = tf.feature_column.numeric_column('peak-rpm')
city_mpg = tf.feature_column.numeric_column('city-mpg')
highway_mpg = tf.feature_column.numeric_column('highway-mpg')

# %%
linear_features = [symboling, normalized_losses, make, fuel_type, aspiration, num_of_doors,
                   body_style, drive_wheels, engine_location, wheel_base, length, width,
                   height, curb_weight, engine_type, num_of_cylinders, engine_size, fuel_system,
                   bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg]

# %%
regressor = tf.contrib.learn.LinearRegressor(feature_columns=linear_features)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\hcche\AppData\Local\Temp\tmpwpz9a13i
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002573CDEAEB8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'C:\\Users\\hcche\\AppData\\Local\\Temp\\tmpwpz9a13i'}

# %%
regressor.fit(input_fn=training_input_fn, steps=10000)
# Out:
# WARNING:tensorflow:From c:\users\hcche\appdata\local\programs\python\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\linear.py:173: get_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_global_step
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\hcche\AppData\Local\Temp\tmpwpz9a13i\model.ckpt.
# INFO:tensorflow:loss = 2.67863e+08, step = 1
# INFO:tensorflow:global_step/sec: 137.81
# INFO:tensorflow:loss = 2.73126e+07, step = 101 (0.731 sec)
# INFO:tensorflow:global_step/sec: 218.649
# INFO:tensorflow:loss = 6.96823e+07, step = 201 (0.458 sec)
# INFO:tensorflow:global_step/sec: 220.688
# INFO:tensorflow:loss = 3.98176e+07, step = 301 (0.453 sec)
# INFO:tensorflow:global_step/sec: 213.08
# INFO:tensorflow:loss = 6.56762e+07, step = 401 (0.468 sec)
# INFO:tensorflow:global_step/sec: 224.878
# INFO:tensorflow:loss = 5.09723e+07, step = 501 (0.445 sec)
# INFO:tensorflow:global_step/sec: 225.197
# INFO:tensorflow:loss = 5.01094e+07, step = 601 (0.444 sec)
# INFO:tensorflow:global_step/sec: 221.707
# INFO:tensorflow:loss = 3.85424e+07, step = 701 (0.450 sec)
# INFO:tensorflow:global_step/sec: 224.341
# INFO:tensorflow:loss = 2.48412e+07, step = 801 (0.446 sec)
# INFO:tensorflow:global_step/sec: 213.965
# INFO:tensorflow:loss = 3.33482e+07, step = 901 (0.465 sec)
# INFO:tensorflow:global_step/sec: 202.681
# INFO:tensorflow:loss = 5.03937e+07, step = 1001 (0.496 sec)
# INFO:tensorflow:global_step/sec: 216.154
# INFO:tensorflow:loss = 3.7179e+07, step = 1101 (0.462 sec)
# INFO:tensorflow:global_step/sec: 159.128
# INFO:tensorflow:loss = 2.25487e+07, step = 1201 (0.629 sec)
# INFO:tensorflow:global_step/sec: 161.477
# INFO:tensorflow:loss = 3.01296e+07, step = 1301 (0.633 sec)
# INFO:tensorflow:global_step/sec: 169.905
# INFO:tensorflow:loss = 2.32988e+07, step = 1401 (0.577 sec)
# INFO:tensorflow:global_step/sec: 206.419
# INFO:tensorflow:loss = 3.6295e+07, step = 1501 (0.490 sec)
# INFO:tensorflow:global_step/sec: 199.301
# INFO:tensorflow:loss = 2.71475e+07, step = 1601 (0.493 sec)
# INFO:tensorflow:global_step/sec: 191.275
# INFO:tensorflow:loss = 2.50303e+07, step = 1701 (0.527 sec)
# INFO:tensorflow:global_step/sec: 152.383
# INFO:tensorflow:loss = 2.54457e+07, step = 1801 (0.653 sec)
# INFO:tensorflow:global_step/sec: 164.476
# INFO:tensorflow:loss = 2.89601e+07, step = 1901 (0.610 sec)
# INFO:tensorflow:global_step/sec: 200.795
# INFO:tensorflow:loss = 2.32334e+07, step = 2001 (0.497 sec)
# INFO:tensorflow:global_step/sec: 212.456
# INFO:tensorflow:loss = 2.86235e+07, step = 2101 (0.471 sec)
# INFO:tensorflow:global_step/sec: 217.516
# INFO:tensorflow:loss = 3.15895e+07, step = 2201 (0.459 sec)
# INFO:tensorflow:global_step/sec: 220.347
# INFO:tensorflow:loss = 2.0005e+07, step = 2301 (0.453 sec)
# INFO:tensorflow:global_step/sec: 215.174
# INFO:tensorflow:loss = 1.77083e+07, step = 2401 (0.466 sec)
# INFO:tensorflow:global_step/sec: 185.384
# INFO:tensorflow:loss = 1.34275e+07, step = 2501 (0.537 sec)
# INFO:tensorflow:global_step/sec: 208.79
# INFO:tensorflow:loss = 2.51912e+07, step = 2601 (0.480 sec)
# INFO:tensorflow:global_step/sec: 220.281
# INFO:tensorflow:loss = 3.28329e+07, step = 2701 (0.455 sec)
# INFO:tensorflow:global_step/sec: 216.693
# INFO:tensorflow:loss = 2.96085e+07, step = 2801 (0.460 sec)
# INFO:tensorflow:global_step/sec: 220.298
# INFO:tensorflow:loss = 3.12845e+07, step = 2901 (0.456 sec)
# INFO:tensorflow:global_step/sec: 209.018
# INFO:tensorflow:loss = 2.36225e+07, step = 3001 (0.477 sec)
# INFO:tensorflow:global_step/sec: 196.111
# INFO:tensorflow:loss = 1.79421e+07, step = 3101 (0.510 sec)
# INFO:tensorflow:global_step/sec: 219.556
# INFO:tensorflow:loss = 1.30925e+07, step = 3201 (0.454 sec)
# INFO:tensorflow:global_step/sec: 219.778
# INFO:tensorflow:loss = 1.85341e+07, step = 3301 (0.458 sec)
# INFO:tensorflow:global_step/sec: 217.224
# INFO:tensorflow:loss = 3.81562e+07, step = 3401 (0.458 sec)
# INFO:tensorflow:global_step/sec: 183.357
# INFO:tensorflow:loss = 2.51304e+07, step = 3501 (0.552 sec)
# INFO:tensorflow:global_step/sec: 195.382
# INFO:tensorflow:loss = 2.65308e+07, step = 3601 (0.504 sec)
# INFO:tensorflow:global_step/sec: 159.236
# INFO:tensorflow:loss = 1.8593e+07, step = 3701 (0.637 sec)
# INFO:tensorflow:global_step/sec: 188.885
# INFO:tensorflow:loss = 1.99857e+07, step = 3801 (0.524 sec)
# INFO:tensorflow:global_step/sec: 192.895
# INFO:tensorflow:loss = 2.29242e+07, step = 3901 (0.523 sec)
# INFO:tensorflow:global_step/sec: 160.863
# INFO:tensorflow:loss = 2.5385e+07, step = 4001 (0.617 sec)
# INFO:tensorflow:global_step/sec: 132.26
# INFO:tensorflow:loss = 1.91049e+07, step = 4101 (0.755 sec)
# INFO:tensorflow:global_step/sec: 131.519
# INFO:tensorflow:loss = 1.30023e+07, step = 4201 (0.763 sec)
# INFO:tensorflow:global_step/sec: 149.371
# INFO:tensorflow:loss = 2.02691e+07, step = 4301 (0.667 sec)
# INFO:tensorflow:global_step/sec: 160.808
# INFO:tensorflow:loss = 3.0382e+07, step = 4401 (0.624 sec)
# INFO:tensorflow:global_step/sec: 146.881
# INFO:tensorflow:loss = 2.65223e+07, step = 4501 (0.679 sec)
# INFO:tensorflow:global_step/sec: 187.121
# INFO:tensorflow:loss = 1.97884e+07, step = 4601 (0.531 sec)
# INFO:tensorflow:global_step/sec: 191.091
# INFO:tensorflow:loss = 1.99861e+07, step = 4701 (0.522 sec)
# INFO:tensorflow:global_step/sec: 211.606
# INFO:tensorflow:loss = 1.48585e+07, step = 4801 (0.474 sec)
# INFO:tensorflow:global_step/sec: 173.408
# INFO:tensorflow:loss = 2.9676e+07, step = 4901 (0.583 sec)
# INFO:tensorflow:global_step/sec: 189.291
# INFO:tensorflow:loss = 3.37487e+07, step = 5001 (0.522 sec)
# INFO:tensorflow:global_step/sec: 224.472
# INFO:tensorflow:loss = 1.47492e+07, step = 5101 (0.444 sec)
# INFO:tensorflow:global_step/sec: 203.892
# INFO:tensorflow:loss = 2.27089e+07, step = 5201 (0.493 sec)
# INFO:tensorflow:global_step/sec: 211.18
# INFO:tensorflow:loss = 2.07895e+07, step = 5301 (0.472 sec)
# INFO:tensorflow:global_step/sec: 220.19
# INFO:tensorflow:loss = 2.73904e+07, step = 5401 (0.454 sec)
# INFO:tensorflow:global_step/sec: 203.303
# INFO:tensorflow:loss = 2.7851e+07, step = 5501 (0.491 sec)
# INFO:tensorflow:global_step/sec: 217.405
# INFO:tensorflow:loss = 1.68419e+07, step = 5601 (0.461 sec)
# INFO:tensorflow:global_step/sec: 209.492
# INFO:tensorflow:loss = 2.04899e+07, step = 5701 (0.476 sec)
# INFO:tensorflow:global_step/sec: 219.95
# INFO:tensorflow:loss = 3.52667e+07, step = 5801 (0.455 sec)
# INFO:tensorflow:global_step/sec: 214.433
# INFO:tensorflow:loss = 3.62789e+07, step = 5901 (0.466 sec)
# INFO:tensorflow:global_step/sec: 221.646
# INFO:tensorflow:loss = 2.56994e+07, step = 6001 (0.452 sec)
# INFO:tensorflow:global_step/sec: 192.189
# INFO:tensorflow:loss = 2.48807e+07, step = 6101 (0.526 sec)
# INFO:tensorflow:global_step/sec: 197.379
# INFO:tensorflow:loss = 3.05032e+07, step = 6201 (0.503 sec)
# INFO:tensorflow:global_step/sec: 194.404
# INFO:tensorflow:loss = 1.99714e+07, step = 6301 (0.513 sec)
# INFO:tensorflow:global_step/sec: 126.18
# INFO:tensorflow:loss = 2.46259e+07, step = 6401 (0.801 sec)
# INFO:tensorflow:global_step/sec: 207.248
# INFO:tensorflow:loss = 2.64345e+07, step = 6501 (0.474 sec)
# INFO:tensorflow:global_step/sec: 142.491
# INFO:tensorflow:loss = 2.00902e+07, step = 6601 (0.704 sec)
# INFO:tensorflow:global_step/sec: 192.84
# INFO:tensorflow:loss = 2.44536e+07, step = 6701 (0.517 sec)
# INFO:tensorflow:global_step/sec: 216.554
# INFO:tensorflow:loss = 1.86927e+07, step = 6801 (0.463 sec)
# INFO:tensorflow:global_step/sec: 145.084
# INFO:tensorflow:loss = 2.99062e+07, step = 6901 (0.695 sec)
# INFO:tensorflow:global_step/sec: 120.808
# INFO:tensorflow:loss = 1.2776e+07, step = 7001 (0.825 sec)
# INFO:tensorflow:global_step/sec: 181.343
# INFO:tensorflow:loss = 1.03789e+07, step = 7101 (0.548 sec)
# INFO:tensorflow:global_step/sec: 195.355
# INFO:tensorflow:loss = 8.46063e+06, step = 7201 (0.511 sec)
# INFO:tensorflow:global_step/sec: 201.685
# INFO:tensorflow:loss = 3.04823e+07, step = 7301 (0.496 sec)
# INFO:tensorflow:global_step/sec: 213.667
# INFO:tensorflow:loss = 2.26703e+07, step = 7401 (0.469 sec)
# INFO:tensorflow:global_step/sec: 205.448
# INFO:tensorflow:loss = 1.98461e+07, step = 7501 (0.486 sec)
# INFO:tensorflow:global_step/sec: 207.744
# INFO:tensorflow:loss = 1.91326e+07, step = 7601 (0.482 sec)
# INFO:tensorflow:global_step/sec: 204.109
# INFO:tensorflow:loss = 1.3092e+07, step = 7701 (0.490 sec)
# INFO:tensorflow:global_step/sec: 214.101
# INFO:tensorflow:loss = 2.43536e+07, step = 7801 (0.467 sec)
# INFO:tensorflow:global_step/sec: 215.903
# INFO:tensorflow:loss = 2.13401e+07, step = 7901 (0.464 sec)
# INFO:tensorflow:global_step/sec: 212.247
# INFO:tensorflow:loss = 1.60149e+07, step = 8001 (0.471 sec)
# INFO:tensorflow:global_step/sec: 199.277
# INFO:tensorflow:loss = 1.56256e+07, step = 8101 (0.501 sec)
# INFO:tensorflow:global_step/sec: 173.625
# INFO:tensorflow:loss = 2.8568e+07, step = 8201 (0.577 sec)
# INFO:tensorflow:global_step/sec: 204.863
# INFO:tensorflow:loss = 1.49496e+07, step = 8301 (0.487 sec)
# INFO:tensorflow:global_step/sec: 207.439
# INFO:tensorflow:loss = 2.3783e+07, step = 8401 (0.482 sec)
# INFO:tensorflow:global_step/sec: 215.083
# INFO:tensorflow:loss = 2.42016e+07, step = 8501 (0.465 sec)
# INFO:tensorflow:global_step/sec: 215.96
# INFO:tensorflow:loss = 2.35592e+07, step = 8601 (0.465 sec)
# INFO:tensorflow:global_step/sec: 209.923
# INFO:tensorflow:loss = 2.11474e+07, step = 8701 (0.474 sec)
# INFO:tensorflow:global_step/sec: 214.423
# INFO:tensorflow:loss = 2.31882e+07, step = 8801 (0.467 sec)
# INFO:tensorflow:global_step/sec: 209.468
# INFO:tensorflow:loss = 1.32174e+07, step = 8901 (0.476 sec)
# INFO:tensorflow:global_step/sec: 212.07
# INFO:tensorflow:loss = 1.09905e+07, step = 9001 (0.472 sec)
# INFO:tensorflow:global_step/sec: 213.175
# INFO:tensorflow:loss = 2.32457e+07, step = 9101 (0.470 sec)
# INFO:tensorflow:global_step/sec: 217.402
# INFO:tensorflow:loss = 3.0004e+07, step = 9201 (0.462 sec)
# INFO:tensorflow:global_step/sec: 178.556
# INFO:tensorflow:loss = 1.97742e+07, step = 9301 (0.559 sec)
# INFO:tensorflow:global_step/sec: 209.985
# INFO:tensorflow:loss = 1.50581e+07, step = 9401 (0.474 sec)
# INFO:tensorflow:global_step/sec: 214.538
# INFO:tensorflow:loss = 3.8163e+07, step = 9501 (0.467 sec)
# INFO:tensorflow:global_step/sec: 207.307
# INFO:tensorflow:loss = 2.21148e+07, step = 9601 (0.482 sec)
# INFO:tensorflow:global_step/sec: 207.312
# INFO:tensorflow:loss = 1.23522e+07, step = 9701 (0.482 sec)
# INFO:tensorflow:global_step/sec: 213.628
# INFO:tensorflow:loss = 2.762e+07, step = 9801 (0.470 sec)
# INFO:tensorflow:global_step/sec: 210.593
# INFO:tensorflow:loss = 1.59791e+07, step = 9901 (0.473 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into C:\Users\hcche\AppData\Local\Temp\tmpwpz9a13i\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.94134e+07.
# LinearRegressor(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._RegressionHead object at 0x000002573C07FF60>, 'feature_columns': [_NumericColumn(key='symboling', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='normalized-losses', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _HashedCategoricalColumn(key='make', hash_bucket_size=50, dtype=tf.string), _VocabularyListCategoricalColumn(key='fuel-type', vocabulary_list=('diesel', 'gas'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='aspiration', vocabulary_list=('std', 'turbo'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='num-of-doors', vocabulary_list=('two', 'four'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='body-style', vocabulary_list=('hardtop', 'wagon', 'sedan', 'hatchback', 'convertible'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='drive-wheels', vocabulary_list=('4wd', 'rwd', 'fwd'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='engine-location', vocabulary_list=('front', 'rear'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _NumericColumn(key='wheel-base', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='length', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='width', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='height', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='curb-weight', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _VocabularyListCategoricalColumn(key='engine-type', vocabulary_list=('dohc', 'dohcv', 'l', 'ohc', 'ohcf', 'ohcv', 'rotor'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='num-of-cylinders', vocabulary_list=('eight', 'five', 'four', 'six', 'three', 'twelve', 'two'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _NumericColumn(key='engine-size', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _VocabularyListCategoricalColumn(key='fuel-system', vocabulary_list=('1bbl', '2bbl', '4bbl', 'idi', 'mfi', 'mpfi', 'spdi', 'spfi'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _NumericColumn(key='bore', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='stroke', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='compression-ratio', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='horsepower', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='peak-rpm', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='city-mpg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='highway-mpg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)], 'optimizer': None, 'gradient_clip_norm': None, 'joint_weights': False})

# %%
regressor.evaluate(input_fn=eval_input_fn)
# Out:
# INFO:tensorflow:Starting evaluation at 2018-01-03-09:52:08
# INFO:tensorflow:Restoring parameters from C:\Users\hcche\AppData\Local\Temp\tmpwpz9a13i\model.ckpt-10000
# INFO:tensorflow:Finished evaluation at 2018-01-03-09:52:10
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 7.99516e+06
# {'global_step': 10000, 'loss': 7995160.0}

# %%
dnn_features = [
    #numerical features
    symboling, normalized_losses, wheel_base, length, width, height, curb_weight, engine_size,
    bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg,    
    # densify categorical features:
    tf.feature_column.indicator_column(make),
    tf.feature_column.indicator_column(fuel_type),
    tf.feature_column.indicator_column(aspiration),
    tf.feature_column.indicator_column(num_of_doors),
    tf.feature_column.indicator_column(body_style),
    tf.feature_column.indicator_column(drive_wheels), 
    tf.feature_column.indicator_column(engine_location),
    tf.feature_column.indicator_column(engine_type),
    tf.feature_column.indicator_column(num_of_cylinders),
    tf.feature_column.indicator_column(fuel_system),
]

# %%
dnnregressor = tf.contrib.learn.DNNRegressor(feature_columns=dnn_features, hidden_units=[50, 30, 10])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\hcche\AppData\Local\Temp\tmp8aym0ig1
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000025740C7F5F8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'C:\\Users\\hcche\\AppData\\Local\\Temp\\tmp8aym0ig1'}

# %%
dnnregressor.fit(input_fn=training_input_fn, steps=10000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\hcche\AppData\Local\Temp\tmp8aym0ig1\model.ckpt.
# INFO:tensorflow:loss = 2.26867e+08, step = 1
# INFO:tensorflow:global_step/sec: 72.4049
# INFO:tensorflow:loss = 3.27852e+07, step = 101 (1.394 sec)
# INFO:tensorflow:global_step/sec: 84.5759
# INFO:tensorflow:loss = 1.55734e+07, step = 201 (1.181 sec)
# INFO:tensorflow:global_step/sec: 128.622
# INFO:tensorflow:loss = 1.37408e+07, step = 301 (0.768 sec)
# INFO:tensorflow:global_step/sec: 218.544
# INFO:tensorflow:loss = 1.29803e+07, step = 401 (0.459 sec)
# INFO:tensorflow:global_step/sec: 195.831
# INFO:tensorflow:loss = 1.53082e+07, step = 501 (0.511 sec)
# INFO:tensorflow:global_step/sec: 215.922
# INFO:tensorflow:loss = 8.32073e+06, step = 601 (0.462 sec)
# INFO:tensorflow:global_step/sec: 214.789
# INFO:tensorflow:loss = 8.17437e+06, step = 701 (0.466 sec)
# INFO:tensorflow:global_step/sec: 218.347
# INFO:tensorflow:loss = 1.0526e+07, step = 801 (0.458 sec)
# INFO:tensorflow:global_step/sec: 209.92
# INFO:tensorflow:loss = 8.34165e+06, step = 901 (0.478 sec)
# INFO:tensorflow:global_step/sec: 212.181
# INFO:tensorflow:loss = 8.08024e+06, step = 1001 (0.469 sec)
# INFO:tensorflow:global_step/sec: 214.841
# INFO:tensorflow:loss = 1.484e+07, step = 1101 (0.466 sec)
# INFO:tensorflow:global_step/sec: 216.666
# INFO:tensorflow:loss = 1.3208e+07, step = 1201 (0.463 sec)
# INFO:tensorflow:global_step/sec: 192.209
# INFO:tensorflow:loss = 7.78042e+06, step = 1301 (0.521 sec)
# INFO:tensorflow:global_step/sec: 208.171
# INFO:tensorflow:loss = 6.51676e+06, step = 1401 (0.479 sec)
# INFO:tensorflow:global_step/sec: 215.487
# INFO:tensorflow:loss = 8.48432e+06, step = 1501 (0.463 sec)
# INFO:tensorflow:global_step/sec: 215.447
# INFO:tensorflow:loss = 9.06428e+06, step = 1601 (0.466 sec)
# INFO:tensorflow:global_step/sec: 202.269
# INFO:tensorflow:loss = 6.52262e+06, step = 1701 (0.505 sec)
# INFO:tensorflow:global_step/sec: 98.2418
# INFO:tensorflow:loss = 7.76823e+06, step = 1801 (1.023 sec)
# INFO:tensorflow:global_step/sec: 158.173
# INFO:tensorflow:loss = 8.91341e+06, step = 1901 (0.618 sec)
# INFO:tensorflow:global_step/sec: 208.267
# INFO:tensorflow:loss = 8.64153e+06, step = 2001 (0.479 sec)
# INFO:tensorflow:global_step/sec: 201.955
# INFO:tensorflow:loss = 5.00429e+06, step = 2101 (0.497 sec)
# INFO:tensorflow:global_step/sec: 209.805
# INFO:tensorflow:loss = 8.62415e+06, step = 2201 (0.474 sec)
# INFO:tensorflow:global_step/sec: 177.495
# INFO:tensorflow:loss = 4.35168e+06, step = 2301 (0.564 sec)
# INFO:tensorflow:global_step/sec: 209.566
# INFO:tensorflow:loss = 5.62589e+06, step = 2401 (0.477 sec)
# INFO:tensorflow:global_step/sec: 132.12
# INFO:tensorflow:loss = 6.30094e+06, step = 2501 (0.758 sec)
# INFO:tensorflow:global_step/sec: 148.04
# INFO:tensorflow:loss = 8.46841e+06, step = 2601 (0.675 sec)
# INFO:tensorflow:global_step/sec: 117.745
# INFO:tensorflow:loss = 7.85235e+06, step = 2701 (0.850 sec)
# INFO:tensorflow:global_step/sec: 164.863
# INFO:tensorflow:loss = 4.69477e+06, step = 2801 (0.603 sec)
# INFO:tensorflow:global_step/sec: 206.949
# INFO:tensorflow:loss = 5.37659e+06, step = 2901 (0.483 sec)
# INFO:tensorflow:global_step/sec: 155.267
# INFO:tensorflow:loss = 7.40381e+06, step = 3001 (0.647 sec)
# INFO:tensorflow:global_step/sec: 168.786
# INFO:tensorflow:loss = 7.44599e+06, step = 3101 (0.602 sec)
# INFO:tensorflow:global_step/sec: 117.371
# INFO:tensorflow:loss = 6.84831e+06, step = 3201 (0.847 sec)
# INFO:tensorflow:global_step/sec: 204.011
# INFO:tensorflow:loss = 4.67791e+06, step = 3301 (0.486 sec)
# INFO:tensorflow:global_step/sec: 149.546
# INFO:tensorflow:loss = 6.66374e+06, step = 3401 (0.678 sec)
# INFO:tensorflow:global_step/sec: 149.584
# INFO:tensorflow:loss = 5.3494e+06, step = 3501 (0.663 sec)
# INFO:tensorflow:global_step/sec: 189.703
# INFO:tensorflow:loss = 7.00082e+06, step = 3601 (0.528 sec)
# INFO:tensorflow:global_step/sec: 160.962
# INFO:tensorflow:loss = 8.80988e+06, step = 3701 (0.618 sec)
# INFO:tensorflow:global_step/sec: 203.455
# INFO:tensorflow:loss = 4.65719e+06, step = 3801 (0.488 sec)
# INFO:tensorflow:global_step/sec: 213.324
# INFO:tensorflow:loss = 6.18616e+06, step = 3901 (0.469 sec)
# INFO:tensorflow:global_step/sec: 223.793
# INFO:tensorflow:loss = 5.45002e+06, step = 4001 (0.446 sec)
# INFO:tensorflow:global_step/sec: 194.039
# INFO:tensorflow:loss = 6.43989e+06, step = 4101 (0.518 sec)
# INFO:tensorflow:global_step/sec: 209.64
# INFO:tensorflow:loss = 8.49753e+06, step = 4201 (0.475 sec)
# INFO:tensorflow:global_step/sec: 220.445
# INFO:tensorflow:loss = 5.50479e+06, step = 4301 (0.453 sec)
# INFO:tensorflow:global_step/sec: 217.74
# INFO:tensorflow:loss = 6.18274e+06, step = 4401 (0.461 sec)
# INFO:tensorflow:global_step/sec: 151.522
# INFO:tensorflow:loss = 3.45072e+06, step = 4501 (0.658 sec)
# INFO:tensorflow:global_step/sec: 154.159
# INFO:tensorflow:loss = 4.54691e+06, step = 4601 (0.654 sec)
# INFO:tensorflow:global_step/sec: 194.78
# INFO:tensorflow:loss = 6.45521e+06, step = 4701 (0.515 sec)
# INFO:tensorflow:global_step/sec: 185.506
# INFO:tensorflow:loss = 7.73741e+06, step = 4801 (0.535 sec)
# INFO:tensorflow:global_step/sec: 208.151
# INFO:tensorflow:loss = 7.53138e+06, step = 4901 (0.478 sec)
# INFO:tensorflow:global_step/sec: 223.408
# INFO:tensorflow:loss = 5.66946e+06, step = 5001 (0.448 sec)
# INFO:tensorflow:global_step/sec: 198.332
# INFO:tensorflow:loss = 3.78859e+06, step = 5101 (0.509 sec)
# INFO:tensorflow:global_step/sec: 146.751
# INFO:tensorflow:loss = 7.31034e+06, step = 5201 (0.686 sec)
# INFO:tensorflow:global_step/sec: 182.113
# INFO:tensorflow:loss = 3.93606e+06, step = 5301 (0.539 sec)
# INFO:tensorflow:global_step/sec: 143.353
# INFO:tensorflow:loss = 8.0212e+06, step = 5401 (0.703 sec)
# INFO:tensorflow:global_step/sec: 194.911
# INFO:tensorflow:loss = 4.80655e+06, step = 5501 (0.507 sec)
# INFO:tensorflow:global_step/sec: 223.016
# INFO:tensorflow:loss = 4.18727e+06, step = 5601 (0.452 sec)
# INFO:tensorflow:global_step/sec: 226.253
# INFO:tensorflow:loss = 4.13539e+06, step = 5701 (0.439 sec)
# INFO:tensorflow:global_step/sec: 221.121
# INFO:tensorflow:loss = 4.21801e+06, step = 5801 (0.452 sec)
# INFO:tensorflow:global_step/sec: 230.409
# INFO:tensorflow:loss = 3.94311e+06, step = 5901 (0.435 sec)
# INFO:tensorflow:global_step/sec: 232.105
# INFO:tensorflow:loss = 5.28772e+06, step = 6001 (0.430 sec)
# INFO:tensorflow:global_step/sec: 228.197
# INFO:tensorflow:loss = 4.01787e+06, step = 6101 (0.438 sec)
# INFO:tensorflow:global_step/sec: 222.758
# INFO:tensorflow:loss = 4.37589e+06, step = 6201 (0.450 sec)
# INFO:tensorflow:global_step/sec: 199.094
# INFO:tensorflow:loss = 4.22016e+06, step = 6301 (0.500 sec)
# INFO:tensorflow:global_step/sec: 233.473
# INFO:tensorflow:loss = 7.27618e+06, step = 6401 (0.432 sec)
# INFO:tensorflow:global_step/sec: 223.96
# INFO:tensorflow:loss = 4.1397e+06, step = 6501 (0.445 sec)
# INFO:tensorflow:global_step/sec: 206.783
# INFO:tensorflow:loss = 3.06663e+06, step = 6601 (0.482 sec)
# INFO:tensorflow:global_step/sec: 227.664
# INFO:tensorflow:loss = 3.48052e+06, step = 6701 (0.441 sec)
# INFO:tensorflow:global_step/sec: 228.902
# INFO:tensorflow:loss = 3.68133e+06, step = 6801 (0.437 sec)
# INFO:tensorflow:global_step/sec: 221.172
# INFO:tensorflow:loss = 3.22917e+06, step = 6901 (0.451 sec)
# INFO:tensorflow:global_step/sec: 229.89
# INFO:tensorflow:loss = 3.16812e+06, step = 7001 (0.435 sec)
# INFO:tensorflow:global_step/sec: 225.501
# INFO:tensorflow:loss = 3.03746e+06, step = 7101 (0.445 sec)
# INFO:tensorflow:global_step/sec: 227.502
# INFO:tensorflow:loss = 3.93018e+06, step = 7201 (0.438 sec)
# INFO:tensorflow:global_step/sec: 218.678
# INFO:tensorflow:loss = 5.8876e+06, step = 7301 (0.457 sec)
# INFO:tensorflow:global_step/sec: 202.684
# INFO:tensorflow:loss = 2.93096e+06, step = 7401 (0.495 sec)
# INFO:tensorflow:global_step/sec: 204.833
# INFO:tensorflow:loss = 6.73268e+06, step = 7501 (0.485 sec)
# INFO:tensorflow:global_step/sec: 221.271
# INFO:tensorflow:loss = 3.63223e+06, step = 7601 (0.458 sec)
# INFO:tensorflow:global_step/sec: 170.819
# INFO:tensorflow:loss = 4.13975e+06, step = 7701 (0.582 sec)
# INFO:tensorflow:global_step/sec: 162.306
# INFO:tensorflow:loss = 4.08229e+06, step = 7801 (0.616 sec)
# INFO:tensorflow:global_step/sec: 156.191
# INFO:tensorflow:loss = 4.07049e+06, step = 7901 (0.639 sec)
# INFO:tensorflow:global_step/sec: 162.476
# INFO:tensorflow:loss = 1.4392e+06, step = 8001 (0.635 sec)
# INFO:tensorflow:global_step/sec: 186.068
# INFO:tensorflow:loss = 5.12467e+06, step = 8101 (0.517 sec)
# INFO:tensorflow:global_step/sec: 227.756
# INFO:tensorflow:loss = 2.80731e+06, step = 8201 (0.438 sec)
# INFO:tensorflow:global_step/sec: 160.688
# INFO:tensorflow:loss = 2.1825e+06, step = 8301 (0.628 sec)
# INFO:tensorflow:global_step/sec: 159.366
# INFO:tensorflow:loss = 3.56868e+06, step = 8401 (0.624 sec)
# INFO:tensorflow:global_step/sec: 222.05
# INFO:tensorflow:loss = 4.54819e+06, step = 8501 (0.451 sec)
# INFO:tensorflow:global_step/sec: 107.002
# INFO:tensorflow:loss = 1.89633e+06, step = 8601 (0.947 sec)
# INFO:tensorflow:global_step/sec: 119.193
# INFO:tensorflow:loss = 1.32381e+06, step = 8701 (0.830 sec)
# INFO:tensorflow:global_step/sec: 131.769
# INFO:tensorflow:loss = 2.06012e+06, step = 8801 (0.761 sec)
# INFO:tensorflow:global_step/sec: 137.812
# INFO:tensorflow:loss = 3.0996e+06, step = 8901 (0.720 sec)
# INFO:tensorflow:global_step/sec: 211.186
# INFO:tensorflow:loss = 1.95128e+06, step = 9001 (0.472 sec)
# INFO:tensorflow:global_step/sec: 202.29
# INFO:tensorflow:loss = 1.52374e+06, step = 9101 (0.494 sec)
# INFO:tensorflow:global_step/sec: 169.876
# INFO:tensorflow:loss = 1.19118e+06, step = 9201 (0.588 sec)
# INFO:tensorflow:global_step/sec: 205.914
# INFO:tensorflow:loss = 3.2842e+06, step = 9301 (0.486 sec)
# INFO:tensorflow:global_step/sec: 226.672
# INFO:tensorflow:loss = 2.63733e+06, step = 9401 (0.442 sec)
# INFO:tensorflow:global_step/sec: 219.26
# INFO:tensorflow:loss = 2.54894e+06, step = 9501 (0.455 sec)
# INFO:tensorflow:global_step/sec: 219.371
# INFO:tensorflow:loss = 4.05714e+06, step = 9601 (0.455 sec)
# INFO:tensorflow:global_step/sec: 214.722
# INFO:tensorflow:loss = 3.08011e+06, step = 9701 (0.467 sec)
# INFO:tensorflow:global_step/sec: 210.279
# INFO:tensorflow:loss = 2.55871e+06, step = 9801 (0.477 sec)
# INFO:tensorflow:global_step/sec: 220.684
# INFO:tensorflow:loss = 2.0953e+06, step = 9901 (0.454 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into C:\Users\hcche\AppData\Local\Temp\tmp8aym0ig1\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.20687e+06.
# DNNRegressor(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._RegressionHead object at 0x0000025740C7FAC8>, 'hidden_units': [50, 30, 10], 'feature_columns': (_NumericColumn(key='symboling', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='normalized-losses', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='wheel-base', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='length', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='width', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='height', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='curb-weight', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='engine-size', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='bore', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='stroke', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='compression-ratio', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='horsepower', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='peak-rpm', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='city-mpg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='highway-mpg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _IndicatorColumn(categorical_column=_HashedCategoricalColumn(key='make', hash_bucket_size=50, dtype=tf.string)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='fuel-type', vocabulary_list=('diesel', 'gas'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='aspiration', vocabulary_list=('std', 'turbo'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='num-of-doors', vocabulary_list=('two', 'four'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='body-style', vocabulary_list=('hardtop', 'wagon', 'sedan', 'hatchback', 'convertible'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='drive-wheels', vocabulary_list=('4wd', 'rwd', 'fwd'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='engine-location', vocabulary_list=('front', 'rear'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='engine-type', vocabulary_list=('dohc', 'dohcv', 'l', 'ohc', 'ohcf', 'ohcv', 'rotor'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='num-of-cylinders', vocabulary_list=('eight', 'five', 'four', 'six', 'three', 'twelve', 'two'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='fuel-system', vocabulary_list=('1bbl', '2bbl', '4bbl', 'idi', 'mfi', 'mpfi', 'spdi', 'spfi'), dtype=tf.string, default_value=-1, num_oov_buckets=0))), 'optimizer': None, 'activation_fn': <function relu at 0x0000025733617378>, 'dropout': None, 'gradient_clip_norm': None, 'embedding_lr_multipliers': None, 'input_layer_min_slice_size': None})

# %%
dnnregressor.evaluate(input_fn=eval_input_fn)
# Out:
# INFO:tensorflow:Starting evaluation at 2018-01-03-09:53:17
# INFO:tensorflow:Restoring parameters from C:\Users\hcche\AppData\Local\Temp\tmp8aym0ig1\model.ckpt-10000
# INFO:tensorflow:Finished evaluation at 2018-01-03-09:53:18
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 1.31596e+07
# {'global_step': 10000, 'loss': 13159593.0}

# %%
def experiment_fn(run_config, params):
  # This function makes an Experiment, containing an Estimator and inputs for training and evaluation.
  # You can use params and config here to customize the Estimator depending on the cluster or to use
  # hyperparameter tuning.

  # Collect information for training
  return tf.contrib.learn.Experiment(estimator=tf.contrib.learn.LinearRegressor(
                                     feature_columns=linear_features, config=run_config),
                                     train_input_fn=training_input_fn,
                                     train_steps=10000,
                                     eval_input_fn=eval_input_fn)

# %%
import shutil
shutil.rmtree("/tmp/output_dir", ignore_errors=True)
tf.contrib.learn.learn_runner.run(experiment_fn, run_config=tf.contrib.learn.RunConfig(model_dir="/tmp/output_dir"))
# Out:
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000257438A67B8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/output_dir'}
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# WARNING:tensorflow:From c:\users\hcche\appdata\local\programs\python\python36\lib\site-packages\tensorflow\contrib\learn\python\learn\monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/output_dir\model.ckpt.
# INFO:tensorflow:Starting evaluation at 2018-01-03-09:53:34
# INFO:tensorflow:Restoring parameters from /tmp/output_dir\model.ckpt-1
# INFO:tensorflow:Evaluation [1/100]
# INFO:tensorflow:Finished evaluation at 2018-01-03-09:53:35
# INFO:tensorflow:Saving dict for global step 1: global_step = 1, loss = 1.43582e+08
# INFO:tensorflow:Validation (step 1): loss = 1.43582e+08, global_step = 1
# INFO:tensorflow:loss = 2.00108e+08, step = 1
# INFO:tensorflow:global_step/sec: 18.6524
# INFO:tensorflow:loss = 3.36183e+07, step = 101 (1.164 sec)
# INFO:tensorflow:global_step/sec: 126.202
# INFO:tensorflow:loss = 7.27461e+07, step = 201 (0.790 sec)
# INFO:tensorflow:global_step/sec: 127.182
# INFO:tensorflow:loss = 5.08935e+07, step = 301 (0.786 sec)
# INFO:tensorflow:global_step/sec: 125.653
# INFO:tensorflow:loss = 6.59704e+07, step = 401 (0.797 sec)
# INFO:tensorflow:global_step/sec: 119.982
# INFO:tensorflow:loss = 4.02974e+07, step = 501 (0.833 sec)
# INFO:tensorflow:global_step/sec: 125.871
# INFO:tensorflow:loss = 2.56663e+07, step = 601 (0.793 sec)
# INFO:tensorflow:global_step/sec: 119.228
# INFO:tensorflow:loss = 3.84479e+07, step = 701 (0.842 sec)
# INFO:tensorflow:global_step/sec: 122.379
# INFO:tensorflow:loss = 3.47254e+07, step = 801 (0.816 sec)
# INFO:tensorflow:global_step/sec: 126.875
# INFO:tensorflow:loss = 2.80488e+07, step = 901 (0.787 sec)
# INFO:tensorflow:global_step/sec: 125.718
# INFO:tensorflow:loss = 1.9923e+07, step = 1001 (0.795 sec)
# INFO:tensorflow:global_step/sec: 126.283
# INFO:tensorflow:loss = 3.94426e+07, step = 1101 (0.792 sec)
# INFO:tensorflow:global_step/sec: 125.092
# INFO:tensorflow:loss = 2.31268e+07, step = 1201 (0.798 sec)
# INFO:tensorflow:global_step/sec: 121.318
# INFO:tensorflow:loss = 2.35665e+07, step = 1301 (0.825 sec)
# INFO:tensorflow:global_step/sec: 116.085
# INFO:tensorflow:loss = 2.84191e+07, step = 1401 (0.861 sec)
# INFO:tensorflow:global_step/sec: 124.602
# INFO:tensorflow:loss = 4.34039e+07, step = 1501 (0.803 sec)
# INFO:tensorflow:global_step/sec: 125.535
# INFO:tensorflow:loss = 3.2516e+07, step = 1601 (0.797 sec)
# INFO:tensorflow:global_step/sec: 127.794
# INFO:tensorflow:loss = 2.57149e+07, step = 1701 (0.784 sec)
# INFO:tensorflow:global_step/sec: 126.795
# INFO:tensorflow:loss = 2.96382e+07, step = 1801 (0.787 sec)
# INFO:tensorflow:global_step/sec: 126.107
# INFO:tensorflow:loss = 1.47665e+07, step = 1901 (0.793 sec)
# INFO:tensorflow:global_step/sec: 125.941
# INFO:tensorflow:loss = 4.11398e+07, step = 2001 (0.795 sec)
# INFO:tensorflow:global_step/sec: 113.431
# INFO:tensorflow:loss = 1.37267e+07, step = 2101 (0.881 sec)
# INFO:tensorflow:global_step/sec: 122.208
# INFO:tensorflow:loss = 3.50901e+07, step = 2201 (0.819 sec)
# INFO:tensorflow:global_step/sec: 124.934
# INFO:tensorflow:loss = 3.07735e+07, step = 2301 (0.801 sec)
# INFO:tensorflow:global_step/sec: 124.973
# INFO:tensorflow:loss = 2.27595e+07, step = 2401 (0.800 sec)
# INFO:tensorflow:global_step/sec: 125.773
# INFO:tensorflow:loss = 1.22444e+07, step = 2501 (0.795 sec)
# INFO:tensorflow:global_step/sec: 122.43
# INFO:tensorflow:loss = 3.30905e+07, step = 2601 (0.817 sec)
# INFO:tensorflow:global_step/sec: 114.316
# INFO:tensorflow:loss = 2.23273e+07, step = 2701 (0.875 sec)
# INFO:tensorflow:global_step/sec: 125.572
# INFO:tensorflow:loss = 2.95895e+07, step = 2801 (0.796 sec)
# INFO:tensorflow:global_step/sec: 125.823
# INFO:tensorflow:loss = 1.54265e+07, step = 2901 (0.795 sec)
# INFO:tensorflow:global_step/sec: 124.625
# INFO:tensorflow:loss = 2.44131e+07, step = 3001 (0.801 sec)
# INFO:tensorflow:global_step/sec: 126.155
# INFO:tensorflow:loss = 2.04141e+07, step = 3101 (0.794 sec)
# INFO:tensorflow:global_step/sec: 126.97
# INFO:tensorflow:loss = 2.99669e+07, step = 3201 (0.788 sec)
# INFO:tensorflow:global_step/sec: 125.905
# INFO:tensorflow:loss = 2.43291e+07, step = 3301 (0.793 sec)
# INFO:tensorflow:global_step/sec: 112.174
# INFO:tensorflow:loss = 2.19929e+07, step = 3401 (0.892 sec)
# INFO:tensorflow:global_step/sec: 124.394
# INFO:tensorflow:loss = 2.38112e+07, step = 3501 (0.807 sec)
# INFO:tensorflow:global_step/sec: 124.022
# INFO:tensorflow:loss = 3.33129e+07, step = 3601 (0.802 sec)
# INFO:tensorflow:global_step/sec: 123.077
# INFO:tensorflow:loss = 1.09426e+07, step = 3701 (0.814 sec)
# INFO:tensorflow:global_step/sec: 120.04
# INFO:tensorflow:loss = 2.06705e+07, step = 3801 (0.832 sec)
# INFO:tensorflow:global_step/sec: 124.888
# INFO:tensorflow:loss = 3.88521e+07, step = 3901 (0.801 sec)
# INFO:tensorflow:global_step/sec: 101.697
# INFO:tensorflow:loss = 1.52043e+07, step = 4001 (0.983 sec)
# INFO:tensorflow:global_step/sec: 109.057
# INFO:tensorflow:loss = 1.64064e+07, step = 4101 (0.917 sec)
# INFO:tensorflow:global_step/sec: 125.862
# INFO:tensorflow:loss = 4.60169e+07, step = 4201 (0.795 sec)
# INFO:tensorflow:global_step/sec: 125.659
# INFO:tensorflow:loss = 1.65413e+07, step = 4301 (0.796 sec)
# INFO:tensorflow:global_step/sec: 124.562
# INFO:tensorflow:loss = 2.75555e+07, step = 4401 (0.812 sec)
# INFO:tensorflow:global_step/sec: 77.2515
# INFO:tensorflow:loss = 2.91269e+07, step = 4501 (1.286 sec)
# INFO:tensorflow:global_step/sec: 97.2308
# INFO:tensorflow:loss = 2.69061e+07, step = 4601 (1.029 sec)
# INFO:tensorflow:global_step/sec: 97.5028
# INFO:tensorflow:loss = 1.98589e+07, step = 4701 (1.025 sec)
# INFO:tensorflow:global_step/sec: 85.3258
# INFO:tensorflow:loss = 1.58859e+07, step = 4801 (1.170 sec)
# INFO:tensorflow:global_step/sec: 71.0799
# INFO:tensorflow:loss = 1.9507e+07, step = 4901 (1.409 sec)
# INFO:tensorflow:global_step/sec: 76.6927
# INFO:tensorflow:loss = 1.88059e+07, step = 5001 (1.313 sec)
# INFO:tensorflow:global_step/sec: 84.7463
# INFO:tensorflow:loss = 1.84732e+07, step = 5101 (1.169 sec)
# INFO:tensorflow:global_step/sec: 124.778
# INFO:tensorflow:loss = 3.57949e+07, step = 5201 (0.800 sec)
# INFO:tensorflow:global_step/sec: 63.3969
# INFO:tensorflow:loss = 1.92564e+07, step = 5301 (1.577 sec)
# INFO:tensorflow:global_step/sec: 47.4599
# INFO:tensorflow:loss = 1.87188e+07, step = 5401 (2.111 sec)
# INFO:tensorflow:global_step/sec: 116.08
# INFO:tensorflow:loss = 1.74143e+07, step = 5501 (0.857 sec)
# INFO:tensorflow:global_step/sec: 128.043
# INFO:tensorflow:loss = 2.63593e+07, step = 5601 (0.781 sec)
# INFO:tensorflow:global_step/sec: 121.344
# INFO:tensorflow:loss = 2.06496e+07, step = 5701 (0.825 sec)
# INFO:tensorflow:global_step/sec: 125.221
# INFO:tensorflow:loss = 1.26348e+07, step = 5801 (0.798 sec)
# INFO:tensorflow:global_step/sec: 126.601
# INFO:tensorflow:loss = 1.97064e+07, step = 5901 (0.791 sec)
# INFO:tensorflow:global_step/sec: 124.329
# INFO:tensorflow:loss = 1.27271e+07, step = 6001 (0.803 sec)
# INFO:tensorflow:global_step/sec: 81.7334
# INFO:tensorflow:loss = 3.10252e+07, step = 6101 (1.225 sec)
# INFO:tensorflow:global_step/sec: 125.269
# INFO:tensorflow:loss = 1.85442e+07, step = 6201 (0.797 sec)
# INFO:tensorflow:global_step/sec: 124.727
# INFO:tensorflow:loss = 1.82861e+07, step = 6301 (0.802 sec)
# INFO:tensorflow:global_step/sec: 107.784
# INFO:tensorflow:loss = 3.71072e+07, step = 6401 (0.933 sec)
# INFO:tensorflow:global_step/sec: 88.2642
# INFO:tensorflow:loss = 2.53867e+07, step = 6501 (1.130 sec)
# INFO:tensorflow:global_step/sec: 117.389
# INFO:tensorflow:loss = 1.76848e+07, step = 6601 (0.850 sec)
# INFO:tensorflow:global_step/sec: 114.962
# INFO:tensorflow:loss = 1.50568e+07, step = 6701 (0.870 sec)
# INFO:tensorflow:global_step/sec: 125.914
# INFO:tensorflow:loss = 1.88645e+07, step = 6801 (0.794 sec)
# INFO:tensorflow:global_step/sec: 85.9959
# INFO:tensorflow:loss = 2.74392e+07, step = 6901 (1.163 sec)
# INFO:tensorflow:global_step/sec: 125.333
# INFO:tensorflow:loss = 2.708e+07, step = 7001 (0.797 sec)
# INFO:tensorflow:global_step/sec: 118.692
# INFO:tensorflow:loss = 3.52273e+07, step = 7101 (0.844 sec)
# INFO:tensorflow:global_step/sec: 126.532
# INFO:tensorflow:loss = 1.81042e+07, step = 7201 (0.790 sec)
# INFO:tensorflow:global_step/sec: 115.012
# INFO:tensorflow:loss = 2.15432e+07, step = 7301 (0.869 sec)
# INFO:tensorflow:global_step/sec: 128.737
# INFO:tensorflow:loss = 2.48326e+07, step = 7401 (0.779 sec)
# INFO:tensorflow:global_step/sec: 128.097
# INFO:tensorflow:loss = 2.32039e+07, step = 7501 (0.780 sec)
# INFO:tensorflow:global_step/sec: 128.118
# INFO:tensorflow:loss = 3.41088e+07, step = 7601 (0.781 sec)
# INFO:tensorflow:global_step/sec: 126.467
# INFO:tensorflow:loss = 1.96638e+07, step = 7701 (0.791 sec)
# INFO:tensorflow:global_step/sec: 126.511
# INFO:tensorflow:loss = 2.25034e+07, step = 7801 (0.790 sec)
# INFO:tensorflow:global_step/sec: 121.899
# INFO:tensorflow:loss = 1.81496e+07, step = 7901 (0.823 sec)
# INFO:tensorflow:global_step/sec: 123.198
# INFO:tensorflow:loss = 1.64164e+07, step = 8001 (0.809 sec)
# INFO:tensorflow:global_step/sec: 124.274
# INFO:tensorflow:loss = 2.56607e+07, step = 8101 (0.806 sec)
# INFO:tensorflow:global_step/sec: 128.643
# INFO:tensorflow:loss = 2.20273e+07, step = 8201 (0.776 sec)
# INFO:tensorflow:global_step/sec: 130.475
# INFO:tensorflow:loss = 3.32405e+07, step = 8301 (0.767 sec)
# INFO:tensorflow:global_step/sec: 122.239
# INFO:tensorflow:loss = 1.64939e+07, step = 8401 (0.817 sec)
# INFO:tensorflow:global_step/sec: 126.834
# INFO:tensorflow:loss = 1.67218e+07, step = 8501 (0.790 sec)
# INFO:tensorflow:global_step/sec: 116.172
# INFO:tensorflow:loss = 1.73358e+07, step = 8601 (0.859 sec)
# INFO:tensorflow:global_step/sec: 127.172
# INFO:tensorflow:loss = 1.69918e+07, step = 8701 (0.786 sec)
# INFO:tensorflow:global_step/sec: 92.7701
# INFO:tensorflow:loss = 1.69411e+07, step = 8801 (1.082 sec)
# INFO:tensorflow:global_step/sec: 110.545
# INFO:tensorflow:loss = 1.2913e+07, step = 8901 (0.902 sec)
# INFO:tensorflow:global_step/sec: 126.341
# INFO:tensorflow:loss = 2.36162e+07, step = 9001 (0.791 sec)
# INFO:tensorflow:global_step/sec: 126.785
# INFO:tensorflow:loss = 2.95536e+07, step = 9101 (0.789 sec)
# INFO:tensorflow:global_step/sec: 115.969
# INFO:tensorflow:loss = 1.68655e+07, step = 9201 (0.861 sec)
# INFO:tensorflow:global_step/sec: 124.346
# INFO:tensorflow:loss = 2.55742e+07, step = 9301 (0.805 sec)
# INFO:tensorflow:global_step/sec: 125.904
# INFO:tensorflow:loss = 2.56545e+07, step = 9401 (0.795 sec)
# INFO:tensorflow:global_step/sec: 127.315
# INFO:tensorflow:loss = 2.55172e+07, step = 9501 (0.784 sec)
# INFO:tensorflow:global_step/sec: 126.179
# INFO:tensorflow:loss = 1.72757e+07, step = 9601 (0.792 sec)
# INFO:tensorflow:global_step/sec: 124.994
# INFO:tensorflow:loss = 2.28909e+07, step = 9701 (0.800 sec)
# INFO:tensorflow:global_step/sec: 129.543
# INFO:tensorflow:loss = 2.01523e+07, step = 9801 (0.773 sec)
# INFO:tensorflow:global_step/sec: 116.733
# INFO:tensorflow:loss = 1.71363e+07, step = 9901 (0.856 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/output_dir\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.23123e+07.
# INFO:tensorflow:Starting evaluation at 2018-01-03-09:55:08
# INFO:tensorflow:Restoring parameters from /tmp/output_dir\model.ckpt-10000
# INFO:tensorflow:Evaluation [1/100]
# INFO:tensorflow:Finished evaluation at 2018-01-03-09:55:09
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 8.14523e+06
# ({'global_step': 10000, 'loss': 8145233.0}, [])
